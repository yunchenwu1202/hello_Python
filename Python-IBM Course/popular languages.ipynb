# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Extract information from a given web site
# *   Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
#
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import csv

# %% [markdown]
# Download the webpage at the url

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"
data  = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
soup = BeautifulSoup(data,"lxml")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
table = soup.find('table')

# %%
#Get all rows from the table
data = []
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    language_name = cols[1].getText() # store the value in column 1 as language name
    annual_average_salary = cols[3].getText() # store the value in column 3 as annual_average_salary
    data.append({
        "language_name": language_name,
        "annual_average_salary": annual_average_salary
    })
    print("{}--->{}".format(language_name,annual_average_salary))
# Out:
# Language--->Average Annual Salary
# Python--->$114,383
# Java--->$101,013
# R--->$92,037
# Javascript--->$110,981
# Swift--->$130,801
# C++--->$113,865
# C#--->$88,726
# PHP--->$84,727
# SQL--->$84,793
# Go--->$94,082

# %%
import csv

with open('popular-languages.csv', 'w', newline='') as csvfile:
    fieldnames = ['language_name', 'annual_average_salary']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    print(data)
    for item in data:
        writer.writerow(item)
# Out:
# [{'language_name': 'Language', 'annual_average_salary': 'Average Annual Salary'}, {'language_name': 'Python', 'annual_average_salary': '$114,383'}, {'language_name': 'Java', 'annual_average_salary': '$101,013'}, {'language_name': 'R', 'annual_average_salary': '$92,037'}, {'language_name': 'Javascript', 'annual_average_salary': '$110,981'}, {'language_name': 'Swift', 'annual_average_salary': '$130,801'}, {'language_name': 'C++', 'annual_average_salary': '$113,865'}, {'language_name': 'C#', 'annual_average_salary': '$88,726'}, {'language_name': 'PHP', 'annual_average_salary': '$84,727'}, {'language_name': 'SQL', 'annual_average_salary': '$84,793'}, {'language_name': 'Go', 'annual_average_salary': '$94,082'}]

# %%
import os
os.getcwd()
# Out:
# '/resources/labs/module 1/Web Scraping'

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01).
